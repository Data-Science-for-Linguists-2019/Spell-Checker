# %% [markdown]
# ## NEW REPLACEMENT
# ## Exploring ELI data frame
# #### Ting-Wei Shen, tis50@pitt.edu, Mar19, 2019

# %% [markdown]
# ### Loading chosen data

# %%
# Import all packages on top
import nltk, glob, re
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# Turn off pretty printing 
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
sns.set_style('darkgrid')

# %% [markdown]
# - First, check about answer.csv

# %%
df_answer = pd.read_csv("./data/answer.csv")
print(df_answer.shape)
df_answer.head(10)
# Out:
# (46239, 6)
#    answer_id  question_id anon_id  user_file_id  \
# 0          1            5     eq0          7505
# 1          2            5     am8          7506
# 2          3           12     dk5          7507
# 3          4           13     dk5          7507
# 4          5           12     ad1          7508
# 5          6           13     ad1          7508
# 6          7           12     eg5          7509
# 7          8           13     eg5          7509
# 8          9           12     ad1          7510
# 9         10           13     ad1          7510
#
#                                                 text  is_deleted
# 0  I met my friend Nife while I was studying in a...           0
# 1  Ten years ago, I met a women on the train betw...           0
# 2  In my country we usually don't use tea bags. F...           0
# 3              I organized the instructions by time.           0
# 4  First, prepare a port, loose tea, and cup.\nSe...           0
# 5                                            By time           0
# 6  First, prepare your cup, loose tea or bag tea,...           0
# 7  I organized the instructions by time, beacause...           0
# 8  First, prepare a port, loose tea, and cup.\nSe...           0
# 9                                            By time           0

# %% [markdown]
# - I choose student_id(anon_id), question_id and text data to help me know the dataframe. Who write the essay with what kind of questions.
#
# - What we need are anon_id, question_id and text data.

# %%
df_eli = pd.DataFrame()
df_eli = df_answer[['anon_id', 'question_id', 'text']]
print(df_eli.shape)
df_eli.head()
# Out:
# (46239, 3)
#   anon_id  question_id                                               text
# 0     eq0            5  I met my friend Nife while I was studying in a...
# 1     am8            5  Ten years ago, I met a women on the train betw...
# 2     dk5           12  In my country we usually don't use tea bags. F...
# 3     dk5           13              I organized the instructions by time.
# 4     ad1           12  First, prepare a port, loose tea, and cup.\nSe...

# %% [markdown]
# - Second, check about student information

# %%
df_student = pd.read_csv("./data/student_information.csv")
print(df_student.shape)
df_student.head()
# Out:
# (913, 21)
#   anon_id  gender  birth_year native_language language_used_at_home  \
# 0     ez9    Male        1978          Arabic                Arabic
# 1     gm3    Male        1980          Arabic                Arabic
# 2     fg5    Male        1938          Nepali                Nepali
# 3     ce5  Female        1984          Korean                Korean
# 4     fi7  Female        1982          Korean       Korean;Japanese
#
#   language_used_at_home_now non_native_language_1 yrs_of_study_lang1  \
# 0                       NaN               English  more than 5 years
# 1                       NaN               English  more than 5 years
# 2                       NaN               English  more than 5 years
# 3                       NaN               English  more than 5 years
# 4                       NaN               English  more than 5 years
#
#    study_in_classroom_lang1  \
# 0                       1.0
# 1                       1.0
# 2                       1.0
# 3                       1.0
# 4                       1.0
#
#                                  ways_of_study_lang1        ...         \
# 0  Studied grammar;Worked in pairs/groups;Studied...        ...
# 1  Studied grammar;Had a native-speaker teacher;S...        ...
# 2  Studied grammar;Worked in pairs/groups;Had a n...        ...
# 3  Studied grammar;Worked in pairs/groups;Had a n...        ...
# 4  Studied grammar;Had a native-speaker teacher;S...        ...
#
#   yrs_of_study_lang2 study_in_classroom_lang2  \
# 0   less than 1 year                      0.0
# 1                NaN                      0.0
# 2   less than 1 year                      1.0
# 3          1-2 years                      1.0
# 4   less than 1 year                      1.0
#
#                                  ways_of_study_lang2 non_native_language_3  \
# 0                                  Studied by myself                   NaN
# 1                                                NaN                   NaN
# 2  Studied grammar;Worked in pairs/groups;Had a n...                 Hindi
# 3  Studied grammar;Studied vocabulary;Listened to...                   NaN
# 4  Studied grammar;Studied vocabulary;Listened to...                French
#
#   yrs_of_study_lang3 study_in_classroom_lang3  \
# 0                NaN                      0.0
# 1                NaN                      0.0
# 2  more than 5 years                      0.0
# 3                NaN                      0.0
# 4          1-2 years                      1.0
#
#                                  ways_of_study_lang3          createddate  \
# 0                                                NaN  2006-01-30 15:07:18
# 1                                                NaN  2006-01-30 15:07:28
# 2                                  Studied by myself  2006-01-30 15:07:45
# 3                                                NaN  2006-01-30 15:07:49
# 4  Studied grammar;Studied vocabulary;Listened to...  2006-01-30 15:07:52
#
#           modifieddate    course_history
# 0  2006-03-14 15:13:37     6;12;18;24;30
# 1  2006-03-14 15:12:49     6;12;24;30;38
# 2  2006-03-14 15:11:36             18;24
# 3  2006-03-14 15:12:24  6;12;24;30;38;56
# 4  2006-03-14 15:12:17     6;12;24;30;38
#
# [5 rows x 21 columns]

# %% [markdown]
# - Let's merge student information

# %%
df_student_trim = df_student[['anon_id', 'gender', 'native_language']]
df_eli = pd.merge(df_eli, df_student_trim, on='anon_id', how='left')
print(df_eli.shape)
df_eli.head()
# Out:
# (46239, 5)
#   anon_id  question_id                                               text  \
# 0     eq0            5  I met my friend Nife while I was studying in a...
# 1     am8            5  Ten years ago, I met a women on the train betw...
# 2     dk5           12  In my country we usually don't use tea bags. F...
# 3     dk5           13              I organized the instructions by time.
# 4     ad1           12  First, prepare a port, loose tea, and cup.\nSe...
#
#    gender native_language
# 0    Male          Arabic
# 1  Female            Thai
# 2  Female         Turkish
# 3  Female         Turkish
# 4  Female          Korean

# %%
# Let's rename the column to help us recognize.
df_eli = df_eli.rename(columns={'anon_id':'student_id'})
df_eli.head()
# Out:
#   student_id  question_id                                               text  \
# 0        eq0            5  I met my friend Nife while I was studying in a...
# 1        am8            5  Ten years ago, I met a women on the train betw...
# 2        dk5           12  In my country we usually don't use tea bags. F...
# 3        dk5           13              I organized the instructions by time.
# 4        ad1           12  First, prepare a port, loose tea, and cup.\nSe...
#
#    gender native_language
# 0    Male          Arabic
# 1  Female            Thai
# 2  Female         Turkish
# 3  Female         Turkish
# 4  Female          Korean

# %% [markdown]
# - The dataframe looks great.
#
# - How about adding question column?

# %%
df_question = pd.read_csv("./data/question.csv")
print(df_question.shape)
df_question.head()
# Out:
# (6138, 16)
#    question_id  question_type_id  user_file_id  question_category_id  \
# 0            1                 2          7430                   NaN
# 1            2                 2          7430                   NaN
# 2            3                 2          7430                   NaN
# 3            4                 4          7495                   NaN
# 4            5                 1          7496                   NaN
#
#    question_parent_id explanation  \
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
#
#                                                 stem choiceA choiceB choiceC  \
# 0  Answer the question.  Write a complete sentenc...     NaN     NaN     NaN
# 1  Answer the question.  Write a complete sentenc...     NaN     NaN     NaN
# 2  Answer the question.  Write a complete sentenc...     NaN     NaN     NaN
# 3  Write an essay on ONE of the following topics....     NaN     NaN     NaN
# 4  Write a paragraph  about a relatioship that is...     NaN     NaN     NaN
#
#   choiceD  allow_text  order_num  is_deleted  org_level direction
# 0     NaN           1          1           0        NaN       NaN
# 1     NaN           1          2           0        NaN       NaN
# 2     NaN           1          3           0        NaN       NaN
# 3     NaN           1          1           0        NaN       NaN
# 4     NaN           1          1           0        NaN       NaN

# %% [markdown]
# - Select question_id and stem(question) only.

# %%
df_question_trim = df_question[['question_id', 'stem']]
df_question_trim = df_question_trim.rename(columns={'stem':'question'})
print(df_question_trim.shape)
df_question_trim.head()
# Out:
# (6138, 2)
#    question_id                                           question
# 0            1  Answer the question.  Write a complete sentenc...
# 1            2  Answer the question.  Write a complete sentenc...
# 2            3  Answer the question.  Write a complete sentenc...
# 3            4  Write an essay on ONE of the following topics....
# 4            5  Write a paragraph  about a relatioship that is...

# %%
df_eli = pd.merge(df_eli, df_question_trim, on='question_id', how='left')
print(df_eli.shape)
df_eli.head()
# Out:
# (46239, 6)
#   student_id  question_id                                               text  \
# 0        eq0            5  I met my friend Nife while I was studying in a...
# 1        am8            5  Ten years ago, I met a women on the train betw...
# 2        dk5           12  In my country we usually don't use tea bags. F...
# 3        dk5           13              I organized the instructions by time.
# 4        ad1           12  First, prepare a port, loose tea, and cup.\nSe...
#
#    gender native_language                                           question
# 0    Male          Arabic  Write a paragraph  about a relatioship that is...
# 1  Female            Thai  Write a paragraph  about a relatioship that is...
# 2  Female         Turkish  In five sentences or less, give instructions o...
# 3  Female         Turkish  How do you organize the instructions: by time,...
# 4  Female          Korean  In five sentences or less, give instructions o...

# %% [markdown]
# - Since it is private data, I just choose sample data - about 500 to represent.
# - Then store the data as a new csv file.

# %%
df_eli_short = df_eli.sample(n = 500, random_state = 1)

# %%
print(df_eli_short.shape)
df_eli_short.head()
# Out:
# (500, 6)
#       student_id  question_id  \
# 43439        gu2         5796
# 753          cq4           37
# 45003        ay8         5990
# 16101        ff4         2358
# 23749        cp5         3229
#
#                                                     text  gender  \
# 43439  They see the online shopping do pollution but ...     NaN
# 753    1-Mismanagement\nSentence: So if they were nom...  Female
# 45003       I was working out in the gym.GHABBAN.wav.mp3     NaN
# 16101  it's getting out of control. Something you sta...    Male
# 23749  This tree has a very rigid trunk, I can not cu...    Male
#
#       native_language                                           question
# 43439             NaN  Chapter 5: "A Cleaner Way to Shop?"  \n\nChoos...
# 753            Arabic  For each of the following words, write the sen...
# 45003             NaN         What were  you doing at 8:00 this morning?
# 16101          French  What does the phrase "it's getting out of hand...
# 23749          Arabic  Write an original creative sentence using a vo...

# %% [markdown]
# - For the fair use, I have to eliminate personal information, so I just look through every text data. And mark the data with personal information.

# %%
# print all data with index count, mark the data with personal information
# just print first 5 to represent
# mark index 112,117,251,352,354,392,424,441
count = 0
for x in df_eli_short.text[:5]:
    print('----------------------------')
    print(count)
    print(x)
    count = count + 1
# Out:
# ----------------------------
# 0
# They see the online shopping do pollution but I am disagree with the author.
# I had heard that it is more energy efficient to do online shopping, even home delivery of groceries. Having products delivered to your home would have a smaller carbon footprint since. there is a single truck bringing goods to several people's homes as opposed to those individual people all getting in their cars and getting their items separately. I think similar to public transportation. When you have a communal way of transporting multiple things or people, it's better than each thing or person travelling separately.
# ----------------------------
# 1
# 1-Mismanagement
# Sentence: So if they were nominated there would be no question of mismanagement of funds.
# Part of speech: Noun
# Definition: he is in charge financial.
# 2-Demonstration
# Sentence: In fact, they claim that Victor was helping to organize a demonstration against the employment policies of Crowly Engineering.
# Part of speech: Noun
# Definition: An action, fact, etc .that proves that someone or something has particular quality, ability, emotion, etc.
# 3-Orgainaize
# Sentence: E.X. 2
# Part of speech: Verb
# Definition: To form UNION or persuade people to join one.
# 4-Disagreement
# Sentence: Mr. Crowly and his son, Victor had some very public disagreements on the construction of government housing for the poor.
# Part of speech: Noun
# Definition: A situation in which people express different opinions about something .
# 5-Religious
# Sentence: Interviews with their friends show that they did not want their children to attend religious school.
# 6-Construction
# Sentence: E.X. 4
# Part of speech: Noun
# Definition: The process or method of building something large such as a house, road.
# ----------------------------
# 2
# I was working out in the gym.GHABBAN.wav.mp3
# ----------------------------
# 3
# it's getting out of control. Something you start and then don't master it.
# ----------------------------
# 4
# This tree has a very rigid trunk, I can not cut by saw.

# %% [markdown]
# - Drop personal information

# %%
df_eli_short = df_eli_short.drop(df_eli_short.index[[112,117,251,352,354,392,424,441]])

# %% [markdown]
# - It looks like the dataframe is good

# %%
print(df_eli_short.shape)
df_eli_short.head()
# Out:
# (492, 6)
#       student_id  question_id  \
# 43439        gu2         5796
# 753          cq4           37
# 45003        ay8         5990
# 16101        ff4         2358
# 23749        cp5         3229
#
#                                                     text  gender  \
# 43439  They see the online shopping do pollution but ...     NaN
# 753    1-Mismanagement\nSentence: So if they were nom...  Female
# 45003       I was working out in the gym.GHABBAN.wav.mp3     NaN
# 16101  it's getting out of control. Something you sta...    Male
# 23749  This tree has a very rigid trunk, I can not cu...    Male
#
#       native_language                                           question
# 43439             NaN  Chapter 5: "A Cleaner Way to Shop?"  \n\nChoos...
# 753            Arabic  For each of the following words, write the sen...
# 45003             NaN         What were  you doing at 8:00 this morning?
# 16101          French  What does the phrase "it's getting out of hand...
# 23749          Arabic  Write an original creative sentence using a vo...

# %% [markdown]
# - save the file as sample data

# %%
#df_eli_short.to_csv("./data/df_eli_short.csv")

# %% [markdown]
# ## Linguistic Analysis
# ### 1. Text length as token count
# - Let's count text length
# - In this part, nltk.word_tokenize return error caused by the wrong input first. That is because some text is stored in "float" type, and word_tokenize only accepts "string" format. I have to set every text into "string" format first, then utilize word_tokenize().

# %%
def getTokens(txt):
    txt = str(txt)
    x = nltk.word_tokenize(txt)
    return x

# %%
df_eli_short['tokens'] = df_eli_short.text.map(getTokens)

# %%
df_eli_short.head()
# Out:
#       student_id  question_id  \
# 43439        gu2         5796
# 753          cq4           37
# 45003        ay8         5990
# 16101        ff4         2358
# 23749        cp5         3229
#
#                                                     text  gender  \
# 43439  They see the online shopping do pollution but ...     NaN
# 753    1-Mismanagement\nSentence: So if they were nom...  Female
# 45003       I was working out in the gym.GHABBAN.wav.mp3     NaN
# 16101  it's getting out of control. Something you sta...    Male
# 23749  This tree has a very rigid trunk, I can not cu...    Male
#
#       native_language                                           question  \
# 43439             NaN  Chapter 5: "A Cleaner Way to Shop?"  \n\nChoos...
# 753            Arabic  For each of the following words, write the sen...
# 45003             NaN         What were  you doing at 8:00 this morning?
# 16101          French  What does the phrase "it's getting out of hand...
# 23749          Arabic  Write an original creative sentence using a vo...
#
#                                                   tokens
# 43439  [They, see, the, online, shopping, do, polluti...
# 753    [1-Mismanagement, Sentence, :, So, if, they, w...
# 45003  [I, was, working, out, in, the, gym.GHABBAN.wa...
# 16101  [it, 's, getting, out, of, control, ., Somethi...
# 23749  [This, tree, has, a, very, rigid, trunk, ,, I,...

# %%
df_eli_short['token_count'] = df_eli_short.tokens.map(len)
df_eli_short.head()
# Out:
#       student_id  question_id  \
# 43439        gu2         5796
# 753          cq4           37
# 45003        ay8         5990
# 16101        ff4         2358
# 23749        cp5         3229
#
#                                                     text  gender  \
# 43439  They see the online shopping do pollution but ...     NaN
# 753    1-Mismanagement\nSentence: So if they were nom...  Female
# 45003       I was working out in the gym.GHABBAN.wav.mp3     NaN
# 16101  it's getting out of control. Something you sta...    Male
# 23749  This tree has a very rigid trunk, I can not cu...    Male
#
#       native_language                                           question  \
# 43439             NaN  Chapter 5: "A Cleaner Way to Shop?"  \n\nChoos...
# 753            Arabic  For each of the following words, write the sen...
# 45003             NaN         What were  you doing at 8:00 this morning?
# 16101          French  What does the phrase "it's getting out of hand...
# 23749          Arabic  Write an original creative sentence using a vo...
#
#                                                   tokens  token_count
# 43439  [They, see, the, online, shopping, do, polluti...          109
# 753    [1-Mismanagement, Sentence, :, So, if, they, w...          198
# 45003  [I, was, working, out, in, the, gym.GHABBAN.wa...            7
# 16101  [it, 's, getting, out, of, control, ., Somethi...           17
# 23749  [This, tree, has, a, very, rigid, trunk, ,, I,...           15

# %% [markdown]
# - There are a lot of short text that less than 100 words. If we took a look at the questions, we can understand that students may be asked to answer just in one word.
# - For example, question_id '1866' - 'Look at the word "warriors" in paragraph 14.  Does it mean a) soldiers or b) hard workers?'

# %%
df_eli_short[df_eli_short.token_count == 1]
# Out:
#       student_id  question_id         text  gender native_language  \
# 12368        dz9         1866            a  Female        Japanese
# 10979        ec9         1651            a    Male          Korean
# 19519        cn1         2753            t  Female         Spanish
# 27560        az3         3798     offended  Female       Taiwanese
# 8498         bm1         1304            a     NaN             NaN
# 38423        fm5         5123  supplanted     Male          Arabic
# 35611        ao2         4816            C    Male          Arabic
# 10531        aa8         1630            c  Female          Korean
# 18994        cy6         2679           is  Female         Spanish
# 36348        ex3         4953            C    Male          Korean
# 16293        cx0         2401        judge  Female         Chinese
# 26089        cm8         3566       Unless  Female         Russian
# 5094         gg2          767            c  Female          Korean
# 5556         di3          737     finished    Male          Arabic
# 3925         bs1          525         that  Female        Japanese
# 14332        aa8         2128       damage  Female          Korean
# 5236         fi1          775            a  Female         Chinese
# 35300        aw6         4811            c     NaN             NaN
# 8850         dz9         1388        avoid  Female        Japanese
# 9090         bm3         1450            c    Male          Korean
# 44289        cq8         5918            5     NaN             NaN
# 8409         fg9         1305            a    Male          Arabic
# 42990        db2         5728      initial     NaN             NaN
# 8811         ff2         1393      courage  Female         Chinese
# 13765        bm7         2058     Exciting  Female      Portuguese
# 4143         ca5          511     Internet    Male          Arabic
# 3991         fi5          531        which  Female          Korean
# 19610        db3         2753            T    Male          Arabic
# 23222        bu1         3173     actively  Female        Japanese
# 8373         bs1         1305            0  Female        Japanese
# 8253         fh9         1265          The  Female        Japanese
# 5199         bs1          772            b  Female        Japanese
# 8863         gv1         1390   inflexible    Male          Korean
# 19041        gb1         2703          ate    Male           Other
# 13460        dc6         1991            b  Female         Spanish
# 3813         df0          468        where  Female        Japanese
# 3907         ei2          527          who  Female         Chinese
# 5031         es9          770            d  Female          Korean
# 19508        cl1         2755        false    Male          Arabic
# 41889        gx1         5591   10/23/2011     NaN             NaN
# 28307        cp5         3905      Robbery    Male          Arabic
# 4008         ey9          528          who     NaN             NaN
# 5795         dd9          992         must    Male          Korean
# 5235         fi1          774            c  Female         Chinese
# 6888         ft2         1134            d  Female          Korean
# 12112        bz1         1839            D    Male         Chinese
# 19159        ef1         2733        yhryr    Male          Korean
# 19473        gd7         2759            T    Male          Arabic
# 3894         gk3          524        whose    Male         Turkish
#
#                                                 question        tokens  \
# 12368  Look at the word "warriors" in paragraph 14.  ...           [a]
# 10979  Look at the word "compounded" in paragraph 13....           [a]
# 19519                                             T or F           [t]
# 27560  Choose a vocabulary word from the article and ...    [offended]
# 8498   American Proverb: “The way to ______ man’s hea...           [a]
# 38423                                         dislocated  [supplanted]
# 35611  The topic of the third reading is\n\na.  the s...           [C]
# 10531  to test out (6)\n\na.  to stop something\nb.  ...           [c]
# 18994         Grammar _____ (be) the best class all day!          [is]
# 36348                              It _______ right now.           [C]
# 16293                                       evaluate (v)       [judge]
# 26089  ________ it stops raining, we won't be able to...      [Unless]
# 5094   When I was a child, my family ______ a horse. ...           [c]
# 5556   Some students will begin university studies af...    [finished]
# 3925   My sister, ___ I haven't seen for 3 years, is ...        [that]
# 14332                       feat, damage, accomplishment      [damage]
# 5236   Have you ever had _____ dream about winning th...           [a]
# 35300  What does "that" in the last sentence of the s...           [c]
# 8850   Luis becomes very sick when he eats corn.  He ...       [avoid]
# 9090   Look at the word "argue"  in paragraph 1, sent...           [c]
# 44289               How many ELI classes are you taking?           [5]
# 8409   My dog is afraid of _______ lightning—she alwa...           [a]
# 42990                           first, at the outset (i)     [initial]
# 8811   It is important for ELI students to have _____...     [courage]
# 13765  What does the word "vibrant" (paragraphs 1 and...    [Exciting]
# 4143   What modern invention helps people take course...    [Internet]
# 3991    The book ___ your brother wants is on the table.       [which]
# 19610                                             T or F           [T]
# 23222  Students learn faster when they are _____ usin...    [actively]
# 8373   My dog is afraid of _______ lightning—she alwa...           [0]
# 8253   ______ Middle East is the home of many ancient...         [The]
# 5199   There are only ___________ days left in the Sp...           [b]
# 8863   The crime victim gave the police _____________...  [inflexible]
# 19041  I ___________________ (eat) ice cream for brea...         [ate]
# 13460  What does the word "opens" mean in the first p...           [b]
# 3813   You should go to Washington, DC, __________ th...       [where]
# 3907   I have 3 brothers.  The brother ___ lives in N...         [who]
# 5031   ______ the U.S. for the first time, the touris...           [d]
# 19508  T or F\nExplain:  What made you choose your an...       [false]
# 41889                      Date the reading was written:  [10/23/2011]
# 28307  Choose a vocabulary word from the article and ...     [Robbery]
# 4008   I want to practice my Spanish, but I don't kno...         [who]
# 5795   The longest river in the world is \na. the Nil...        [must]
# 5235   ... 3 people ______ in a hit-and-run accident....           [c]
# 6888   What does "reflect" mean in paragraph 5? (Writ...           [d]
# 12112  Why didn't the school put an air conditioner i...           [D]
# 19159  Complete the Review Tests in you book on pages...       [yhryr]
# 19473                                             T or F           [T]
# 3894   I could see that Lisa was a wonderful woman, _...       [whose]
#
#        token_count
# 12368            1
# 10979            1
# 19519            1
# 27560            1
# 8498             1
# 38423            1
# 35611            1
# 10531            1
# 18994            1
# 36348            1
# 16293            1
# 26089            1
# 5094             1
# 5556             1
# 3925             1
# 14332            1
# 5236             1
# 35300            1
# 8850             1
# 9090             1
# 44289            1
# 8409             1
# 42990            1
# 8811             1
# 13765            1
# 4143             1
# 3991             1
# 19610            1
# 23222            1
# 8373             1
# 8253             1
# 5199             1
# 8863             1
# 19041            1
# 13460            1
# 3813             1
# 3907             1
# 5031             1
# 19508            1
# 41889            1
# 28307            1
# 4008             1
# 5795             1
# 5235             1
# 6888             1
# 12112            1
# 19159            1
# 19473            1
# 3894             1

# %%
len(df_eli_short[df_eli_short.token_count == 1])
# Out:
# 49

# %%
df_eli_short[df_eli_short.token_count == 1].iloc[0,5]
# Out:
# 'Look at the word "warriors" in paragraph 14.  Does it mean a) soldiers or b) hard workers?'

# %% [markdown]
# - Student just answer 'a'. That is really reasonable.
# - However, this situation may cause that the whole dataframe contains many one word texts.

# %%
df_eli_short[df_eli_short.token_count == 1].iloc[0,2]
# Out:
# 'a'

# %% [markdown]
# - If we counted the value by number of tokens, we can find that data has a lot of short texts.

# %%
df_eli_short.token_count.value_counts().head(10)
# Out:
# 1     49
# 8     13
# 5     13
# 2     12
# 6     12
# 7     12
# 15    11
# 12    11
# 16    11
# 13    10
# Name: token_count, dtype: int64

# %%
df_tokens = df_eli_short.token_count.value_counts(bins=20).head(17)
df_tokens.name = ''
df_tokens
# Out:
# (-0.262, 64.05]      315
# (64.05, 127.1]        56
# (127.1, 190.15]       47
# (190.15, 253.2]       19
# (253.2, 316.25]       13
# (442.35, 505.4]        7
# (316.25, 379.3]        7
# (379.3, 442.35]        7
# (568.45, 631.5]        5
# (631.5, 694.55]        4
# (505.4, 568.45]        4
# (694.55, 757.6]        2
# (1009.8, 1072.85]      2
# (820.65, 883.7]        1
# (946.75, 1009.8]       1
# (1072.85, 1135.9]      1
# (1198.95, 1262.0]      1
# Name: , dtype: int64

# %%
df_tokens.plot.pie(shadow=True, startangle=90, figsize=(5, 5))
plt.title('Figure 1: Token counts', fontsize=16)
plt.show()

# %% [markdown]
# - How about choosing top five categories?

# %%
df_tokens_5 = df_eli_short.token_count.value_counts(bins=20).head(5)
df_tokens_5.name = ''
df_tokens_5
# Out:
# (-0.262, 64.05]    315
# (64.05, 127.1]      56
# (127.1, 190.15]     47
# (190.15, 253.2]     19
# (253.2, 316.25]     13
# Name: , dtype: int64

# %%
df_tokens_5.plot.pie(shadow=True, startangle=50, figsize=(5, 5))
plt.title('Figure 2: Token counts (top five categories)', fontsize=16)
plt.show()

# %% [markdown]
# ### Summary
#
# - Now, we know that the length of texts are not distributed well. Most of them are under 65 tokens.

# %% [markdown]
# ### 2. Value count by native language
# - Maybe we can do some simple analysis, such as native language, to help us look through the data.

# %%
df_native = df_eli_short.native_language.value_counts()
df_native
# Out:
# Arabic        113
# Korean         97
# Chinese        81
# Japanese       28
# Spanish        15
# Thai           15
# Turkish        12
# Portuguese      7
# French          5
# Other           5
# Taiwanese       5
# Russian         2
# English         2
# Italian         2
# Polish          1
# Swedish         1
# Farsi           1
# Name: native_language, dtype: int64

# %%
df_native.plot(kind='bar', figsize=(12,5))   # Not saving output as a plot object
plt.title('Figure 3: number of text by L1', fontsize=16)          # Must use plt.title(), plt.xlabel() etc. 
plt.xlabel('L1 (native language of students)', fontsize=12)
plt.ylabel('Number of text', fontsize=12)
plt.show()

# %% [markdown]
# - The output above is counted by text. We may want to look at the number of total students and the number of essay they write.
# - Let's go through the data.

# %%
df_eli_short.student_id.value_counts().head(10)
# Out:
# es9    5
# cx0    5
# bs1    4
# gv1    4
# cp5    4
# bq0    3
# fp9    3
# dv1    3
# fh1    3
# cq4    3
# Name: student_id, dtype: int64

# %%
df_eli_short.student_id.value_counts().describe()
# Out:
# count    353.000000
# mean       1.393768
# std        0.715626
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: student_id, dtype: float64

# %%
df_eli_short.student_id.describe()
# Out:
# count     492
# unique    353
# top       es9
# freq        5
# Name: student_id, dtype: object

# %% [markdown]
# ### Summary
#
# - There are 492 texts in the dataframe.
# - These texts are written by 353 students.
# - The max number of essays students wrote is 5.
# - Students write 1.39 essay in average.

# %%
df_eli_short.head()
# Out:
#       student_id  question_id  \
# 43439        gu2         5796
# 753          cq4           37
# 45003        ay8         5990
# 16101        ff4         2358
# 23749        cp5         3229
#
#                                                     text  gender  \
# 43439  They see the online shopping do pollution but ...     NaN
# 753    1-Mismanagement\nSentence: So if they were nom...  Female
# 45003       I was working out in the gym.GHABBAN.wav.mp3     NaN
# 16101  it's getting out of control. Something you sta...    Male
# 23749  This tree has a very rigid trunk, I can not cu...    Male
#
#       native_language                                           question  \
# 43439             NaN  Chapter 5: "A Cleaner Way to Shop?"  \n\nChoos...
# 753            Arabic  For each of the following words, write the sen...
# 45003             NaN         What were  you doing at 8:00 this morning?
# 16101          French  What does the phrase "it's getting out of hand...
# 23749          Arabic  Write an original creative sentence using a vo...
#
#                                                   tokens  token_count
# 43439  [They, see, the, online, shopping, do, polluti...          109
# 753    [1-Mismanagement, Sentence, :, So, if, they, w...          198
# 45003  [I, was, working, out, in, the, gym.GHABBAN.wa...            7
# 16101  [it, 's, getting, out, of, control, ., Somethi...           17
# 23749  [This, tree, has, a, very, rigid, trunk, ,, I,...           15

# %% [markdown]
# - Type token ratio analysis

# %%
df_eli_short['types'] = df_eli_short['tokens'].map(set)

# %%
df_eli_short['type_count'] = df_eli_short['types'].map(len)

# %%
df_eli_short['TTR'] = df_eli_short['type_count'] / df_eli_short['token_count']

# %%
df_eli_short.head()
# Out:
#       student_id  question_id  \
# 43439        gu2         5796
# 753          cq4           37
# 45003        ay8         5990
# 16101        ff4         2358
# 23749        cp5         3229
#
#                                                     text  gender  \
# 43439  They see the online shopping do pollution but ...     NaN
# 753    1-Mismanagement\nSentence: So if they were nom...  Female
# 45003       I was working out in the gym.GHABBAN.wav.mp3     NaN
# 16101  it's getting out of control. Something you sta...    Male
# 23749  This tree has a very rigid trunk, I can not cu...    Male
#
#       native_language                                           question  \
# 43439             NaN  Chapter 5: "A Cleaner Way to Shop?"  \n\nChoos...
# 753            Arabic  For each of the following words, write the sen...
# 45003             NaN         What were  you doing at 8:00 this morning?
# 16101          French  What does the phrase "it's getting out of hand...
# 23749          Arabic  Write an original creative sentence using a vo...
#
#                                                   tokens  token_count  \
# 43439  [They, see, the, online, shopping, do, polluti...          109
# 753    [1-Mismanagement, Sentence, :, So, if, they, w...          198
# 45003  [I, was, working, out, in, the, gym.GHABBAN.wa...            7
# 16101  [it, 's, getting, out, of, control, ., Somethi...           17
# 23749  [This, tree, has, a, very, rigid, trunk, ,, I,...           15
#
#                                                    types  type_count       TTR
# 43439  {home, They, of, their, think, have, see, tran...          79  0.724771
# 753    {very, Victor, 4-Disagreement, An, friends, A,...         116  0.585859
# 45003  {gym.GHABBAN.wav.mp3, I, the, was, working, in...           7  1.000000
# 16101  {of, Something, start, ., then, master, gettin...          15  0.882353
# 23749  {trunk, very, saw, has, cut, ., a, by, rigid, ...          15  1.000000

# %%
import pickle

f = open('df_eli.pkl', 'wb')   # 'wb' instead 'w' for binary file
pickle.dump(df_eli_short, f, -1)       # -1 specifies highest binary protocol
f.close()

# %% [markdown]
# ### Trail part for spell checker.

# %%
from spell import correction

# %%
correction('spellin')
# Out:
# 'spelling'

# %%
df_eli_short.head()
# Out:
#       student_id  question_id  \
# 43439        gu2         5796
# 753          cq4           37
# 45003        ay8         5990
# 16101        ff4         2358
# 23749        cp5         3229
#
#                                                     text  gender  \
# 43439  They see the online shopping do pollution but ...     NaN
# 753    1-Mismanagement\nSentence: So if they were nom...  Female
# 45003       I was working out in the gym.GHABBAN.wav.mp3     NaN
# 16101  it's getting out of control. Something you sta...    Male
# 23749  This tree has a very rigid trunk, I can not cu...    Male
#
#       native_language                                           question  \
# 43439             NaN  Chapter 5: "A Cleaner Way to Shop?"  \n\nChoos...
# 753            Arabic  For each of the following words, write the sen...
# 45003             NaN         What were  you doing at 8:00 this morning?
# 16101          French  What does the phrase "it's getting out of hand...
# 23749          Arabic  Write an original creative sentence using a vo...
#
#                                                   tokens  token_count  \
# 43439  [They, see, the, online, shopping, do, polluti...          109
# 753    [1-Mismanagement, Sentence, :, So, if, they, w...          198
# 45003  [I, was, working, out, in, the, gym.GHABBAN.wa...            7
# 16101  [it, 's, getting, out, of, control, ., Somethi...           17
# 23749  [This, tree, has, a, very, rigid, trunk, ,, I,...           15
#
#                                                    types  type_count       TTR
# 43439  {home, They, of, their, think, have, see, tran...          79  0.724771
# 753    {very, Victor, 4-Disagreement, An, friends, A,...         116  0.585859
# 45003  {gym.GHABBAN.wav.mp3, I, the, was, working, in...           7  1.000000
# 16101  {of, Something, start, ., then, master, gettin...          15  0.882353
# 23749  {trunk, very, saw, has, cut, ., a, by, rigid, ...          15  1.000000

# %%
# !pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /anaconda3/lib/python3.6/site-packages (0.4.0)
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

# find those words that may be misspelled
misspelled = spell.unknown(['something', 'is', 'hapenning', 'here'])

for word in misspelled:
    # Get the one 'most likely' answer
    print(spell.correction(word))
    
    # Get a list of 'likely' options
    print(spell.candidates(word))
# Out:
# happening
# {'henning', 'happening', 'penning'}

# %%
spell.correction('google')
# Out:
# 'goole'

# %%
spell = SpellChecker()  # loads default word frequency list
spell.word_frequency.load_words(['google'])

# %%
spell.correction('google')
# Out:
# 'google'

# %%
spell.known(['microsoft', 'goole'])
# Out:
# {'goole', 'microsoft'}

# %%
dir(spell)
# Out:
# ['_SpellChecker__edit_distance_alt', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '_check_if_should_check', '_distance', '_word_frequency', 'candidates', 'correction', 'distance', 'edit_distance_1', 'edit_distance_2', 'export', 'known', 'split_words', 'unknown', 'word_frequency', 'word_probability']

# %%
help(spell.unknown)
# Out:
# Help on method unknown in module spellchecker.spellchecker:
#
# unknown(words) method of spellchecker.spellchecker.SpellChecker instance
#     The subset of `words` that do not appear in the dictionary
#
#     Args:
#         words (list): List of words to determine which are not in the                 corpus
#     Returns:
#         set: The set of those words from the input that are not in                 the corpus

# %%
spell.unknown(['applk'])
# Out:
# {'applk'}

# %%
help(spell)
# Out:
# Help on SpellChecker in module spellchecker.spellchecker object:
#
# class SpellChecker(builtins.object)
#  |  The SpellChecker class encapsulates the basics needed to accomplish a
#  |  simple spell checking algorithm. It is based on the work by
#  |  Peter Norvig (https://norvig.com/spell-correct.html)
#  |
#  |  Args:
#  |      language (str): The language of the dictionary to load or None             for no dictionary. Supported languages are `en`, `es`, `de`, fr`             and `pt`. Defaults to `en`
#  |      local_dictionary (str): The path to a locally stored word             frequency dictionary; if provided, no language will be loaded
#  |      distance (int): The edit distance to use. Defaults to 2
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key)
#  |      setup easier known checks
#  |
#  |  __getitem__(self, key)
#  |      setup easier frequency checks
#  |
#  |  __init__(self, language='en', local_dictionary=None, distance=2)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  candidates(self, word)
#  |      Generate possible spelling corrections for the provided word up to
#  |      an edit distance of two, if and only when needed
#  |
#  |      Args:
#  |          word (str): The word for which to calculate candidate spellings
#  |      Returns:
#  |          set: The set of words that are possible candidates
#  |
#  |  correction(self, word)
#  |      The most probable correct spelling for the word
#  |
#  |      Args:
#  |          word (str): The word to correct
#  |      Returns:
#  |          str: The most likely candidate
#  |
#  |  edit_distance_1(self, word)
#  |      Compute all strings that are one edit away from `word` using only
#  |      the letters in the corpus
#  |
#  |      Args:
#  |          word (str): The word for which to calculate the edit distance
#  |      Returns:
#  |          set: The set of strings that are edit distance one from the                 provided word
#  |
#  |  edit_distance_2(self, word)
#  |      Compute all strings that are two edits away from `word` using only
#  |      the letters in the corpus
#  |
#  |      Args:
#  |          word (str): The word for which to calculate the edit distance
#  |      Returns:
#  |          set: The set of strings that are edit distance two from the                 provided word
#  |
#  |  export(self, filepath, encoding='utf-8', gzipped=True)
#  |      Export the word frequency list for import in the future
#  |
#  |      Args:
#  |         filepath (str): The filepath to the exported dictionary
#  |         encoding (str): The encoding of the resulting output
#  |         gzipped (bool): Whether to gzip the dictionary or not
#  |
#  |  known(self, words)
#  |      The subset of `words` that appear in the dictionary of words
#  |
#  |      Args:
#  |          words (list): List of words to determine which are in the                 corpus
#  |      Returns:
#  |          set: The set of those words from the input that are in the                 corpus
#  |
#  |  unknown(self, words)
#  |      The subset of `words` that do not appear in the dictionary
#  |
#  |      Args:
#  |          words (list): List of words to determine which are not in the                 corpus
#  |      Returns:
#  |          set: The set of those words from the input that are not in                 the corpus
#  |
#  |  word_probability(self, word, total_words=None)
#  |      Calculate the probability of the `word` being the desired, correct
#  |      word
#  |
#  |      Args:
#  |          word (str): The word for which the word probability is                 calculated
#  |          total_words (int): The total number of words to use in the                 calculation; use the default for using the whole word                 frequency
#  |      Returns:
#  |          float: The probability that the word is the correct word
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  split_words(text)
#  |      Split text into individual `words` using a simple whitespace regex
#  |
#  |      Args:
#  |          text (str): The text to split into individual words
#  |      Returns:
#  |          list(str): A listing of all words in the provided text
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  distance
#  |      int: The maximum edit distance to calculate
#  |
#  |      Note:
#  |          Valid values are 1 or 2; if an invalid value is passed,                 defaults to 2
#  |
#  |  word_frequency
#  |      WordFrequency: An encapsulation of the word frequency `dictionary`
#  |
#  |      Note:
#  |          Not settable

# %%
len(spell.edit_distance_1('applk'))
# Out:
# 526
